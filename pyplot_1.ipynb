# %% [markdown]
# <a href="https://colab.research.google.com/github/ranshu1601/plotting_pyplot_1/blob/main/pyplot_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Plotting With Pyplot

# %% [markdown]
# ## Plot Graph of **Log(x)**

# %%
import numpy as np                                #importing required Libraries 
import matplotlib.pyplot as pl
x=np.linspace(1,5,6) #Generate an array in range 1,5 having 6 elements 
y=np.log(x)
pl.plot(x,y)

# %% [markdown]
# ## plotting Graph of Sin(x) and Cos(x)

# %%
#As we have imported the libraries once we don't need to import them again 
x=np.arange(0.,10,0.1)
a=np.cos(x)
b=np.sin(x)
pl.plot(x,a,'b') #Color code is 'blue' 
pl.plot(x,b,'r') #Color code is 'Red'
pl.show()

# %% [markdown]
# Question :
# Create multiple line charts on common plot where three data ranges are plotted on same chart. The data range(s) to be plotted is/are:
# Data = [[5.,25.,45.,20.],[8.,13.,29.,27.],[9.,29.,27.,39.]]

# %%
# Libraries are Already imported before 
Data = [[5.,25.,45.,20.],[8.,13.,29.,27.],[9.,29.,27.,39.]]
X=np.arange(4)
pl.plot(X,Data[0],color='b',label='range1')
pl.plot(X,Data[1],color='g',label='range2')
pl.plot(X,Data[2],color='r',label='range3')
pl.legend(loc='upper left')
pl.title("MultiRange Line chart ")
pl.xlabel('X')
pl.ylabel('Y')
pl.legend(loc='upper left' )
pl.show()

# %% [markdown]
# ## Saving a Figure

# %%
pl.savefig("graph,pdf") # save the plot of current directory 
pl.savefig("path") # to save the plot at the given path
